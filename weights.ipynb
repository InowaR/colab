# %% [markdown]
# <a href="https://colab.research.google.com/github/InowaR/colab/blob/main/weights.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

X = np.array([[1.0, 1.0, 1.0]])
Y = np.array([[1.0]]).T
w1 = np.random.random((3,3))
w2 = np.random.random((3,1))

for i in range(100):
  S1 = 1 / (1 + np.exp(-(np.dot(X, w1))))
  S2 = 1 / (1 + np.exp(-(np.dot(S1, w2))))
  S2_delta = (Y - S2) * (S2 * (1 - S2))
  S1_delta = S2_delta.dot(w2.T) * (S1 * (1 - S1))
  w1 += X.T.dot(S1_delta)
  w2 += S1.T.dot(S2_delta)
  plt.scatter(w1[0][0], i, color = 'red')
  plt.scatter(w1[0][1], i, color = 'green')
  plt.scatter(w1[0][2], i, color = 'blue')
  plt.scatter(w1[1][0], i, color = 'pink')
  plt.scatter(w1[1][1], i, color = 'orange')
  plt.scatter(w1[1][2], i, color = 'brown')
  plt.scatter(w1[2][0], i, color = 'grey')
  plt.scatter(w1[2][1], i, color = 'indigo')
  plt.scatter(w1[2][2], i, color = 'purple')
  plt.scatter(w2[0], i, color = 'black')
  plt.scatter(w2[1], i, color = 'black')
  plt.scatter(w2[2], i, color = 'black')

test = np.array([[1.0, 1.0, 1.0]])
S1 = 1 / (1 + np.exp(-(np.dot(test, w1))))
S2 = 1 / (1 + np.exp(-(np.dot(S1, w2))))
print(S2)
# Out:
# [[0.95412525]]
