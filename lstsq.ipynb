# %% [markdown]
# <a href="https://colab.research.google.com/github/InowaR/colab/blob/main/lstsq.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Задаем данные (замените на свои данные)
x = np.array([1, 2, 3, 4, 5])
y = np.array([1, 2, 3, 4, 5])

# Матрица для МНК
A = np.vstack([x, np.ones(len(x))]).T

# Решаем систему уравнений методом наименьших квадратов
m, c = np.linalg.lstsq(A, y, rcond=None)[0]

# Строим график
plt.plot(x, y, 'o', label='Данные')
plt.plot(x, m*x + c, 'r', label='Линия регрессии')
plt.legend()
plt.show()
