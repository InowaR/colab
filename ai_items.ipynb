# %% [markdown]
# <a href="https://colab.research.google.com/github/InowaR/colab/blob/main/ai_items.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys

if "google.colab" in sys.modules:
    from google.colab import auth

    auth.authenticate_user()

# %%
from google.colab import userdata

PROJECT_ID = userdata.get('PROJECT_ID')
LOCATION = userdata.get('LOCATION')

# %%
import vertexai
from vertexai.generative_models import GenerativeModel


vertexai.init(project=PROJECT_ID, location=LOCATION)
model = GenerativeModel("gemini-1.0-pro")

# %%
import pandas as pd
from IPython.display import display


df1 = pd.read_csv("КТП_AETZ1.csv")

print(df1.columns)

list_items = '{'

for row in df1.itertuples():
    data = {row[5], row[3]}
    list_items += f'{{"index": {row.Index}, "data": {data}}}, '

list_items += '}'

print(list_items)
# Out:
# Index(['Наименование товара', 'Код ЕНС ТРУ', 'Краткая характеристика',
#        'Доля внутристрановой ценности в %', 'Сертификат товара',
#        'Дата выдачи сертификата', 'Дата окончания сертификата',
#        'Дата добавления товара', 'Дата окончания сертификата.1',
#        'Дата добавления товара.1'],
#       dtype='object')
# ...

# %%
df2 = pd.read_csv("data.csv")

print(df2.columns)

list_all_items = '{'

for row in df2.itertuples():
    data = {row[1], row[2], row[3], row[4], row[5], row[6], row[7], row[8], row[9], row[10], row[11], row[12]}
    list_all_items += f'{{"index": {row.Index}, "data": {data}}}, '

list_items += '}'

print(list_all_items)
# Out:
# Index(['Наименование закупки:', 'Номер лота:', 'Наименование лота:',
#        'Описание лота:', 'Дополнительное\nописание лота:', 'Количество:',
#        'Единица измерения:', 'Места поставки:', 'Срок поставки:',
#        'Описание и требуемые\nфункциональные,\nтехнические,\nкачественные и\nэксплуатационные\nхарактеристики\nзакупаемых товаров',
#        'Наименование\nзакупки:',
#        'Описание и требуемые\nфункциональные,\nтехнические,\nкачественные и\nэксплуатационные\nхарактеристики\nзакупаемых товаров:'],
#       dtype='object')
# ...

# %%
def send_data(prompt):
    response = chat.send_message(prompt)
    print(response.text)


chat = model.start_chat(history=[])

# %%
send_data(f'Привет, давай сыграем в игру. Это первый список товаров, которые производит компания в формате json: {list_items}. Это второй список разных товаров в формате json: {list_all_items}. Из второго списка разных товаров возьми словарь с товаром, который точно подходит к по теме к первому списку товаров. Укажи индекс данного товара во втором списке.')
# Out:
# Товар из второго списка, который **точно подходит** к теме первого списка товаров:
#
# **Индекс:** 9
#
# **Описание товара:**
#
# Комплектная трансформаторная подстанция сельского типа КТП 63кВа-10(6)/0,4 кВ
#
# **Характеристики:**
#
# * мощность 63 кВА
# * с масляным трансформатором
#
# Этот товар соответствует теме первого списка, который включает в себя различные виды трансформаторных подстанций.

# %%
chat.history.clear()
