# %% [markdown]
# <a href="https://colab.research.google.com/github/InowaR/colab/blob/main/kivy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt update
# !sudo apt install -y git zip unzip openjdk-17-jdk python3-pip autoconf libtool pkg-config zlib1g-dev libncurses5-dev libncursesw5-dev libtinfo5 cmake libffi-dev libssl-dev
# !pip3 install --user --upgrade Cython==0.29.33 virtualenv
# Out:
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,027 kB]
# Ign:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy Release [5,713 B]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy Release.gpg [793 B]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,590 kB]
# Hit:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,596 kB]
# ...

# %%
# !git clone https://github.com/kivy/buildozer
# %cd buildozer
# !python setup.py build
# !pip install -e .
# %cd ..
# Out:
# Cloning into 'buildozer'...
# remote: Enumerating objects: 4849, done.
# remote: Counting objects: 100% (841/841), done.
# remote: Compressing objects: 100% (448/448), done.
# remote: Total 4849 (delta 557), reused 628 (delta 390), pack-reused 4008 (from 1)
# Receiving objects: 100% (4849/4849), 1.63 MiB | 4.10 MiB/s, done.
# Resolving deltas: 100% (3069/3069), done.
# /content/buildozer
# running build
# running build_py
# creating build
# creating build/lib
# creating build/lib/buildozer
# copying buildozer/target.py -> build/lib/buildozer
# copying buildozer/__main__.py -> build/lib/buildozer
# copying buildozer/exceptions.py -> build/lib/buildozer
# copying buildozer/jsonstore.py -> build/lib/buildozer
# copying buildozer/sitecustomize.py -> build/lib/buildozer
# copying buildozer/buildops.py -> build/lib/buildozer
# copying buildozer/logger.py -> build/lib/buildozer
# copying buildozer/__init__.py -> build/lib/buildozer
# copying buildozer/specparser.py -> build/lib/buildozer
# ...

# %%
# !git clone https://github.com/Android-for-Python/c4k_photo_example.git
# Out:
# Cloning into 'c4k_photo_example'...
# remote: Enumerating objects: 160, done.
# remote: Counting objects: 100% (128/128), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 160 (delta 60), reused 106 (delta 41), pack-reused 32 (from 1)
# Receiving objects: 100% (160/160), 80.32 KiB | 591.00 KiB/s, done.
# Resolving deltas: 100% (63/63), done.

# %%
# %cd c4k_photo_example/
# Out:
# /content/c4k_photo_example

# %%
# для мобильных устройств, чтобы работал ввод текста в терминал
# !pip install colab-xterm
# %load_ext colabxterm
from IPython.display import clear_output
clear_output()
# %xterm
# Out:
# Launching Xterm...

# %%
# для создания нового buildozer.spec файла
# !buildozer init
# Out:
# Buildozer is running as root!
# This is not recommended, and may lead to problems later.
# Are you sure you want to continue [y/n]? n

# %%
# !buildozer -v android debug
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# [DEBUG]:   	    Found existing installation: pip 23.2.1
# [DEBUG]:   	    Uninstalling pip-23.2.1:
# [DEBUG]:   	      Successfully uninstalled pip-23.2.1
# [DEBUG]:   	Successfully installed pip-24.2
# [INFO]:    Install Cython in case one of the modules needs it to build
# [DEBUG]:   -> running bash -c venv/bin/pip install Cython
# [DEBUG]:   	Ignoring "sys._home = value" override
# [DEBUG]:   	Collecting Cython
# [DEBUG]:   	  Downloading Cython-3.0.11-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# [DEBUG]:   	Downloading Cython-3.0.11-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 65.2 MB/s eta 0:00:00
# [DEBUG]:   	Installing collected packages: Cython
# [DEBUG]:   	Successfully installed Cython-3.0.11
# ...

# %%
# !buildozer android clean
