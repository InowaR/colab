# %% [markdown]
# <a href="https://colab.research.google.com/github/InowaR/colab/blob/main/pillow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from PIL import Image
filename = "1-exgooglerobo.jpg"
with Image.open(filename) as img:
     img.load()
plt.imshow(img)
